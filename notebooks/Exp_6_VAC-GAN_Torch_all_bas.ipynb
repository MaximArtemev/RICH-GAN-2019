# %%
# !pip install comet_ml
# Out:
# Requirement already satisfied: comet_ml in /usr/local/lib/python3.6/dist-packages (3.1.6)
# Requirement already satisfied: jsonschema<3.1.0,>=2.6.0 in /usr/local/lib/python3.6/dist-packages (from comet_ml) (2.6.0)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.6/dist-packages (from comet_ml) (7.352.0)
# Requirement already satisfied: everett[ini]>=1.0.1; python_version >= "3.0" in /usr/local/lib/python3.6/dist-packages (from comet_ml) (1.0.2)
# Requirement already satisfied: comet-git-pure>=0.19.11 in /usr/local/lib/python3.6/dist-packages (from comet_ml) (0.19.16)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.6/dist-packages (from comet_ml) (3.7.4.2)
# Requirement already satisfied: netifaces>=0.10.7 in /usr/local/lib/python3.6/dist-packages (from comet_ml) (0.10.9)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.6/dist-packages (from comet_ml) (2.23.0)
# Requirement already satisfied: wurlitzer>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from comet_ml) (2.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from comet_ml) (1.12.0)
# Requirement already satisfied: websocket-client>=0.55.0 in /usr/local/lib/python3.6/dist-packages (from comet_ml) (0.57.0)
# Requirement already satisfied: configobj; extra == "ini" in /usr/local/lib/python3.6/dist-packages (from everett[ini]>=1.0.1; python_version >= "3.0"->comet_ml) (5.0.6)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from comet-git-pure>=0.19.11->comet_ml) (2020.4.5.1)
# Requirement already satisfied: urllib3>=1.24.1 in /usr/local/lib/python3.6/dist-packages (from comet-git-pure>=0.19.11->comet_ml) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->comet_ml) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->comet_ml) (3.0.4)

# %%
from comet_ml import Experiment

import os
#os.environ["CUDA_VISIBLE_DEVICES"]="3"

# %%
PARTICLES = ['kaon', 'pion', 'proton', 'muon']
MODEL_NAME = "Pytorch_Cramer_All_1layer"

# %%
from sklearn.model_selection import train_test_split
import torch
from torch import nn
import torch.nn.functional as F
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import os
from IPython.display import clear_output
import scipy
from tqdm import tqdm_notebook, tqdm
from torch.autograd import Variable, grad
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/rich_utils')

# %%
import torch_utils_rich_mrartemev as utils_rich

# %% [markdown]
# ## Data

# %%
data_train, data_val, scaler = utils_rich.get_all_particles_dataset(dtype=np.float32, log=True, list_particles=PARTICLES)
# Out:
# Reading and concatenating datasets:
# 	../content/drive/My Drive/data/data_calibsample/kaon2_-_down_2016_.csv
# 	../content/drive/My Drive/data/data_calibsample/kaon2_+_down_2016_.csv
# 	../content/drive/My Drive/data/data_calibsample/kaon2_-_up_2016_.csv
# 	../content/drive/My Drive/data/data_calibsample/kaon2_+_up_2016_.csv
# 	../content/drive/My Drive/data/data_calibsample/kaon_-_down_2016_.csv
# 	../content/drive/My Drive/data/data_calibsample/kaon_+_down_2016_.csv
# 	../content/drive/My Drive/data/data_calibsample/kaon_-_up_2016_.csv
# 	../content/drive/My Drive/data/data_calibsample/kaon_+_up_2016_.csv
# splitting to train/val/test
# fitting the scaler
# scaler train sample size: 2000000
# scaler n_quantiles: 100000, time = 2.0423572063446045
# scaling train set
# scaling test set
# converting dtype to <class 'numpy.float32'>
# Reading and concatenating datasets:
# 	../content/drive/My Drive/data/data_calibsample/pion2_-_down_2016_.csv
# 	../content/drive/My Drive/data/data_calibsample/pion2_+_down_2016_.csv
# 	../content/drive/My Drive/data/data_calibsample/pion2_-_up_2016_.csv
# 	../content/drive/My Drive/data/data_calibsample/pion2_+_up_2016_.csv
# 	../content/drive/My Drive/data/data_calibsample/pion_-_down_2016_.csv
# 	../content/drive/My Drive/data/data_calibsample/pion_+_down_2016_.csv
# 	../content/drive/My Drive/data/data_calibsample/pion_-_up_2016_.csv
# 	../content/drive/My Drive/data/data_calibsample/pion_+_up_2016_.csv
# splitting to train/val/test
# fitting the scaler
# scaler train sample size: 2000000
# scaler n_quantiles: 100000, time = 2.0009660720825195
# scaling train set
# scaling test set
# converting dtype to <class 'numpy.float32'>
# Reading and concatenating datasets:
# 	../content/drive/My Drive/data/data_calibsample/proton_-_down_2016_.csv
# 	../content/drive/My Drive/data/data_calibsample/proton_+_down_2016_.csv
# 	../content/drive/My Drive/data/data_calibsample/proton_-_up_2016_.csv
# 	../content/drive/My Drive/data/data_calibsample/proton_+_up_2016_.csv
# splitting to train/val/test
# fitting the scaler
# scaler train sample size: 1000000
# scaler n_quantiles: 100000, time = 1.1219482421875
# scaling train set
# scaling test set
# converting dtype to <class 'numpy.float32'>
# Reading and concatenating datasets:
# 	../content/drive/My Drive/data/data_calibsample/muon_-_down_2016_.csv
# 	../content/drive/My Drive/data/data_calibsample/muon_+_down_2016_.csv
# 	../content/drive/My Drive/data/data_calibsample/muon_-_up_2016_.csv
# 	../content/drive/My Drive/data/data_calibsample/muon_+_up_2016_.csv
# splitting to train/val/test
# fitting the scaler
# scaler train sample size: 1000000
# scaler n_quantiles: 100000, time = 1.1658439636230469
# scaling train set
# scaling test set
# converting dtype to <class 'numpy.float32'>

# %%
data_train.head()
# Out:
#    RichDLLe  RichDLLk  RichDLLmu  ...  Brunel_ETA  nTracks_Brunel  probe_sWeight
# 0  0.555870 -0.944576   0.475479  ...    1.492709        0.087418       0.053932
# 1 -0.652621  0.301450  -0.531307  ...   -0.691638        0.242183       1.166070
# 2 -0.705267 -2.879602   1.047932  ...   -1.125975       -0.000664      -0.131609
# 3  1.397504  0.254146   1.027402  ...    0.296501       -0.572245       0.433815
# 4 -1.019068 -0.465702  -0.683660  ...   -0.716438        1.162377       1.265090
#
# [5 rows x 13 columns]

# %%
BATCH_SIZE = int(1e3)
LATENT_DIMENSIONS = 64

N_VAL = int(3e5)
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
from itertools import repeat

class ParticleSetTrain(torch.utils.data.Dataset):
    def __init__(self, data):
        self.data = data
    
    def __len__(self):
        return self.data.shape[0]
    
    def __getitem__(self, ind):
        return (self.data[ind, utils_rich.y_count:-1], # X
                self.data[ind, -1], # Weight
                self.data[ind, :utils_rich.y_count], # DLL
                np.argmax(self.data[ind, utils_rich.y_count:utils_rich.y_count + len(PARTICLES)])
               )

class ParticleSet(torch.utils.data.Dataset):
    def __init__(self, data):
        self.data = data
    
    def __len__(self):
        return self.data.shape[0]
    
    def __getitem__(self, ind):
        return (self.data[ind, utils_rich.y_count:-1], # X
                self.data[ind, -1], # Weight
                self.data[ind, :utils_rich.y_count] # DLL
               )
    
def repeater(data_loader):
    for loader in repeat(data_loader):
        for data in loader:
            yield data
    
# https://github.com/pytorch/pytorch/issues/5398
# https://discuss.pytorch.org/t/implementing-an-infinite-loop-dataset-dataloader-combo/35567
train_loader = repeater(torch.utils.data.DataLoader(ParticleSetTrain(data_train.values),
                                                    batch_size=BATCH_SIZE,
                                                    shuffle=True,
                                                    pin_memory=True))

validation_set = {particle: repeater(torch.utils.data.DataLoader(ParticleSet(data_val[data_val['is_{}'.format(particle)] == 1].values),
                                                  batch_size=N_VAL,
                                                  shuffle=False,
                                                  pin_memory=True)) for particle in PARTICLES}

# %%
for i in next(validation_set['kaon']):
    print(i.shape)
# Out:
# torch.Size([300000, 7])
# torch.Size([300000])
# torch.Size([300000, 5])

# %% [markdown]
# ## Model

# %%
CRAMER_DIM = 256
NUM_LAYERS = 5

def get_noise(batch_size, mean=0, std=1):
    return torch.zeros(batch_size, LATENT_DIMENSIONS).normal_(mean, std).to(device)
def get_labels(batch_size, n_classes=len(PARTICLES)):
    return torch.LongTensor(batch_size).random_(0, n_classes).to(device)

class Generator(nn.Module):
    def __init__(self, hidden_size=128, depth=5):
        super(Generator, self).__init__()
        self.label_emb = nn.Embedding(len(PARTICLES), LATENT_DIMENSIONS)
        self.layers = nn.Sequential(
            nn.Linear(LATENT_DIMENSIONS + data_train.shape[1] - 1 - utils_rich.y_count, hidden_size),
            nn.ReLU(),
            *[nn.Sequential(nn.Linear(hidden_size, hidden_size), nn.ReLU()) for _ in range(depth)],
            nn.Linear(hidden_size, utils_rich.y_count),
        )

    def forward(self, x, labels=None, noise=None):
        noise = get_noise(x.shape[0])
        input_gen = torch.mul(self.label_emb(labels), noise)
        return self.layers(torch.cat([x, input_gen], dim=1))

    
class Critic(nn.Module):
    def __init__(self, hidden_size=128, depth=5):
        super(Critic, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(data_train.shape[1] - 1, hidden_size),
            nn.LeakyReLU(0.05),
            *[nn.Sequential(nn.Linear(hidden_size, hidden_size), nn.LeakyReLU(0.05)) for _ in range(depth)],
            nn.Linear(128, CRAMER_DIM)
        )

    def forward(self, x):
        return self.layers(x)

class VAC_Classif(nn.Module):
    def __init__(self, hidden_size=128, depth=5):
        super(VAC_Classif, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(data_train.shape[1] - 1, hidden_size),
            nn.ReLU(),
            *[nn.Sequential(nn.Linear(hidden_size, hidden_size), nn.ReLU()) for _ in range(depth)],
            nn.Linear(hidden_size, len(PARTICLES)),
            nn.Softmax(dim=1)
        )

    def forward(self, x):
        return self.layers(x)


def init_weights(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_uniform_(m.weight)
        m.bias.data.fill_(0.01)

# %%
netG = Generator(depth=NUM_LAYERS).to(device)
netG.apply(init_weights)

netC = Critic(depth=NUM_LAYERS).to(device)
netC.apply(init_weights)

VAC = VAC_Classif(depth=NUM_LAYERS).to(device)
VAC.apply(init_weights)

pass

# %%
device
# Out:
# 'cuda'

# %%
optC = torch.optim.AdamW(netC.parameters())
lr_C = torch.optim.lr_scheduler.ExponentialLR(optimizer=optC, gamma=0.995)
optG = torch.optim.AdamW(netG.parameters())
lr_G = torch.optim.lr_scheduler.ExponentialLR(optimizer=optG, gamma=0.995)
optV = torch.optim.SGD(VAC.parameters(), nesterov=True, momentum=0.9, lr=0.01)
lr_V = torch.optim.lr_scheduler.ExponentialLR(optimizer=optV, gamma=0.995)

# %% [markdown]
# ## Train

# %%
LOGDIR = "/content/drive/My Drive/"
logdir = '/content/drive/My Drive/torch_model_6.pt'

CRITIC_ITERATIONS_CONST = 15
TOTAL_ITERATIONS = int(5e4)
VALIDATION_INTERVAL = 1000

# %%
lambda_pt = lambda i: 20 / np.pi * 2 * torch.atan(torch.tensor(i, dtype=torch.float32, device=device)/1e4)

pt = []
for i in tqdm_notebook(range(50000)):
    pt.append(lambda_pt(i))
    
plt.plot(pt)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
# HBox(children=(IntProgress(value=0, max=50000), HTML(value='')))

# %%
for i in next(train_loader):
    print(i.shape)
# Out:
# torch.Size([1000, 7])
# torch.Size([1000])
# torch.Size([1000, 5])
# torch.Size([1000])

# %%
experiment = Experiment(api_key="k62CZajG08ctPlNYUYRv9YVdO",
                        project_name="rich", workspace="nzinci")
# Out:
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/nzinci/rich/7314e36bb8e34294958b61c6700c6057

# %%
def calc_gradient_penalty(real_data, fake_data, fake_data2):
    alpha = torch.rand(BATCH_SIZE, 1)
    alpha = alpha.expand(real_data.size())
    alpha = alpha.to(device)

    interpolates = alpha * real_data + ((1 - alpha) * fake_data)
    
#     interpolates = torch.Tensor(interpolates, requires_grad=True)

    disc_interpolates = cramer_critic(interpolates, fake_data2)

    gradients = grad(outputs=disc_interpolates, inputs=interpolates,
                     grad_outputs=torch.ones(disc_interpolates.size()).to(device),
                     create_graph=True, retain_graph=True, only_inputs=True)[0]
    # create_graph=True, retain_graph=True, only_inputs=True - crucial for our case

    gradient_penalty = ((gradients.norm(2, dim=1) - 1) ** 2).mean()
    return gradient_penalty

# %%
def cramer_critic(x, y):
    discriminated_x = netC(x)
    discriminated_y = netC(y)
    return torch.norm(discriminated_x - discriminated_y, dim=1) - torch.norm(discriminated_x, dim=1)

# %%
#Load Model
checkpoint = torch.load(logdir)
netC.load_state_dict(checkpoint[MODEL_NAME+'netC_state_dict'])
netG.load_state_dict(checkpoint[MODEL_NAME+'netG_state_dict'])
optC.load_state_dict(checkpoint[MODEL_NAME+'optC_state_dict'])
optG.load_state_dict(checkpoint[MODEL_NAME+'optG_state_dict'])
lr_C.load_state_dict(checkpoint[MODEL_NAME+'lr_C_state_dict'])
lr_G.load_state_dict(checkpoint[MODEL_NAME+'lr_G_state_dict'])

netC.eval()
netG.eval()

# %%
labels_loss = torch.nn.CrossEntropyLoss()

# %%
dtype = torch.cuda.FloatTensor if torch.cuda.is_available() else torch.FloatTensor
for iteration in tqdm(range(10*TOTAL_ITERATIONS), position=0, leave=True):
    # ---- Critic Train ----
    for critic_iter in range(CRITIC_ITERATIONS_CONST):
        x, weight, dlls, signals = [i.to(device).type(dtype) for i in next(train_loader)]
        
        optC.zero_grad()
        
        netC.train()
        netG.eval()
        VAC.eval()
        
        labels = get_labels(x.shape[0], n_classes=len(PARTICLES))
        real_full_0 = torch.cat([dlls, x], dim=1)    
        generated_1 = torch.cat([netG(x, labels=labels), x], dim=1)
        generated_2 = torch.cat([netG(x, labels=labels), x], dim=1)
        
        generator_loss = torch.mean(cramer_critic(real_full_0, generated_2) * weight - 
                                    cramer_critic(generated_1, generated_2) * weight)
        
        # GP
        gradient_penalty = calc_gradient_penalty(real_full_0, generated_1, generated_2)
        critic_loss = lambda_pt(iteration) * gradient_penalty - generator_loss
        critic_loss.backward()
        optC.step()

    # ---- Generator Train ----    
    x, weight, dlls, signals = [i.to(device).type(dtype) for i in next(train_loader)]
    
    netG.train()
    netC.eval()
    VAC.eval()
    
    optG.zero_grad()

    labels = get_labels(x.shape[0], n_classes=len(PARTICLES))
    real_full_0 = torch.cat([dlls, x], dim=1)
    generated_1 = torch.cat([netG(x, labels=labels), x], dim=1)
    generated_2 = torch.cat([netG(x, labels=labels), x], dim=1)
    labels_gen_1 = VAC(generated_1)
    labels_gen_2 = VAC(generated_2)

    classif_loss = (labels_loss(labels_gen_1, labels) + labels_loss(labels_gen_2, labels)) / 2
    generator_loss = (torch.mean(cramer_critic(real_full_0, generated_2) * weight -
                cramer_critic(generated_1, generated_2) * weight) + classif_loss) / 2
    
    generator_loss.backward()
    optG.step()
    
    VAC.train()
    netG.eval()
    netC.eval()
    optV.zero_grad()
    
    x, weight, dlls, signals = [i.to(device).type(dtype) for i in next(train_loader)]

    labels = get_labels(x.shape[0], n_classes=len(PARTICLES))
    real_full_0 = torch.cat([dlls, x], dim=1)
    generated_1 = torch.cat([netG(x, labels=labels), x], dim=1)
    generated_2 = torch.cat([netG(x, labels=labels), x], dim=1)
    labels_gen_1 = VAC(generated_1)
    labels_gen_2 = VAC(generated_2)
    classif_loss = (labels_loss(labels_gen_1, labels) + labels_loss(labels_gen_2, labels)) / 2
    classif_loss.backward()
    optV.step()

    experiment.log_metrics({'Generator loss': generator_loss.item(),
                            'Critic loss': critic_loss.item()},
                            step=iteration)
    lr_C.step()
    lr_G.step()
    lr_V.step()
    
    if iteration % 100 == 0:
        clear_output(False)
        for ind, particle in enumerate(PARTICLES):
            print('particle: {}, epoch: {}'.format(particle, iteration))
            with torch.no_grad():
                x, weight, dlls = [i.to(device).type(dtype) for i in next(validation_set[particle])]
                real_full = torch.cat([dlls, x], dim=1)

                labels = get_labels(x.shape[0], n_classes=len(PARTICLES))
                generated = netG(x, labels=labels)
                fig, axes = plt.subplots(3, 2, figsize=(15, 15))
                for INDEX, ax in zip((0, 1, 2, 3, 4), axes.flatten()):
                    _, bins, _ = ax.hist(dlls[:, INDEX].cpu(),
                                        bins=100,
                                        label="data",
                                        density=True,
                                        weights=weight.cpu())
                    ax.hist(generated[:, INDEX].cpu(),
                            bins=bins,
                            label="generated",
                            alpha=0.5,
                            density=True,
                            weights=weight.cpu())
                    ax.legend()
                    ax.set_title(utils_rich.dll_columns[INDEX])
                experiment.log_figure()
                plt.show()
        torch.save({MODEL_NAME+'netC_state_dict': netC.state_dict(),
            MODEL_NAME+'netG_state_dict': netG.state_dict(),
            MODEL_NAME+'optC_state_dict': optC.state_dict(),
            MODEL_NAME+'optG_state_dict': optG.state_dict(),
            MODEL_NAME+'lr_C_state_dict': lr_C.state_dict(),
            MODEL_NAME+'lr_G_state_dict': lr_G.state_dict(),
            MODEL_NAME+'optV_state_dict': optV.state_dict(),
            MODEL_NAME+'lr_V_state_dict': lr_V.state_dict()
           }, logdir)
experiment.end()
# Out:
# particle: kaon, epoch: 6300
# particle: pion, epoch: 6300
# particle: proton, epoch: 6300
# particle: muon, epoch: 6300
#   1%|▏         | 6357/500000 [2:07:53<118:35:47,  1.16it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-4e50070ac228> in <module>()
#      22         gradient_penalty = calc_gradient_penalty(real_full_0, generated_1, generated_2)
#      23         critic_loss = lambda_pt(iteration) * gradient_penalty - generator_loss
# ---> 24         critic_loss.backward()
#      25         optC.step()
#      26
#
# /usr/local/lib/python3.6/dist-packages/comet_ml/monkey_patching.py in wrapper(*args, **kwargs)
#     290                     )
#     291
# --> 292         return_value = original(*args, **kwargs)
#     293
#     294         # Call after callbacks once we have the return value
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     196                 products. Defaults to ``False``.
#     197         """
# --> 198         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     199
#     200     def register_hook(self, hook):
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      98     Variable._execution_engine.run_backward(
#      99         tensors, grad_tensors, retain_graph, create_graph,
# --> 100         allow_unreachable=True)  # allow_unreachable flag
#     101
#     102
#
# KeyboardInterrupt:

# %%
torch.save({MODEL_NAME+'netC_state_dict': netC.state_dict(),
            MODEL_NAME+'netG_state_dict': netG.state_dict(),
            MODEL_NAME+'optC_state_dict': optC.state_dict(),
            MODEL_NAME+'optG_state_dict': optG.state_dict(),
            MODEL_NAME+'lr_C_state_dict': lr_C.state_dict(),
            MODEL_NAME+'lr_G_state_dict': lr_G.state_dict(),
            MODEL_NAME+'optV_state_dict': optV.state_dict(),
            MODEL_NAME+'lr_V_state_dict': lr_V.state_dict()
           }, logdir)
from sklearn.externals import joblib
os.makedirs('./preprocessors', exist_ok=True)
joblib.dump(scaler, os.path.join('preprocessors', MODEL_NAME) + "_preprocessor.pkl")
# Out:
# ['preprocessors/Pytorch_Cramer_All_1layer_preprocessor.pkl']

# %%
for ind, particle in enumerate(PARTICLES):
    print('particle: {}'.format(particle))
    with torch.no_grad():
        x, weight, dlls = [i.to(device) for i in next(validation_set[particle])]
        real_full = torch.cat([dlls, x], dim=1)

        labels = get_labels(x.shape[0], n_classes=len(PARTICLES))
        generated = netG(x, labels=labels)
        fig, axes = plt.subplots(3, 2, figsize=(15, 15))
        for INDEX, ax in zip((0, 1, 2, 3, 4), axes.flatten()):
            _, bins, _ = ax.hist(dlls[:, INDEX].cpu(),
                                bins=100,
                                label="data",
                                density=True,
                                weights=weight.cpu())
            ax.hist(generated[:, INDEX].cpu(),
                    bins=bins,
                    label="generated",
                    alpha=0.5,
                    density=True,
                    weights=weight.cpu())
            ax.legend()
            ax.set_title(utils_rich.dll_columns[INDEX])
        plt.show()
# Out:
# particle: kaon
# particle: pion
# particle: proton
# particle: muon

# %%
from collections import defaultdict
eval_particles_loader = {particle: torch.utils.data.DataLoader(ParticleSet(
                                        data_val[data_val['is_{}'.format(particle)] == 1].values),
                                        batch_size=N_VAL,
                                        shuffle=False,
                                        pin_memory=True) for particle in PARTICLES}

particles_pred_dlls = defaultdict(list)
for par in eval_particles_loader:
    for batch in tqdm(eval_particles_loader[par], position=0, leave=True):
        x, weight, dlls = [i.to(device) for i in batch]
        labels = get_labels(x.shape[0], n_classes=len(PARTICLES))
        particles_pred_dlls[par].append(netG(x, labels=labels).detach().cpu().numpy())
# Out:
# 100%|██████████| 4/4 [00:16<00:00,  4.19s/it]
# 100%|██████████| 4/4 [00:16<00:00,  4.19s/it]
# 100%|██████████| 2/2 [00:08<00:00,  4.16s/it]
# 100%|██████████| 2/2 [00:08<00:00,  4.11s/it]

# %%
print(data_val.columns)
# Out:
# Index(['RichDLLe', 'RichDLLk', 'RichDLLmu', 'RichDLLp', 'RichDLLbt', 'is_kaon',
#        'is_pion', 'is_proton', 'is_muon', 'Brunel_P', 'Brunel_ETA',
#        'nTracks_Brunel', 'probe_sWeight'],
#       dtype='object')

# %%
data_val_c = data_val.copy()

# %%
data_val_c = data_val_c.drop(['is_kaon', 'is_pion', 'is_proton', 'is_muon'], axis=1)

# %%
pred_data_inversed = {}
val_data_inversed = {}
for i, part in enumerate(particles_pred_dlls):
    pred_dlls = np.concatenate(particles_pred_dlls[part], axis=0)
    pred_data = np.concatenate([pred_dlls, data_val_c[data_val['is_{}'.format(
                                        part)] == 1].values[:, utils_rich.y_count:-1]], axis=1)
    pred_data_inversed[part] = scaler[i].inverse_transform(pred_data)
    val_data_inversed[part] = scaler[i].inverse_transform(data_val_c[data_val['is_{}'.format(
                                        part)] == 1].iloc[:, :-1])

# %%
val_data_inversed_ = {}
for part in PARTICLES:
    val_data_inversed_[part] = pd.DataFrame(val_data_inversed[part], 
                                                columns=data_val_c.columns[:-1])
    for ind, col in enumerate(utils_rich.dll_columns):
        val_data_inversed_[part]["predicted_"+col] = pred_data_inversed[part][:, ind]
    val_data_inversed_[part]['probe_sWeight'] = data_val_c[data_val['is_{}'.format(
                                        part)] == 1]['probe_sWeight']

# %%
class Wrapper:
    def __init__(self, data):
        self.test = data

wrap = lambda x, part: {part: Wrapper(x)}

# %%
from model_testing import eval_model

particle_scores = []
for part, vdata_inv in val_data_inversed_.items():
    scores, bins = eval_model(part, wrap(vdata_inv, part))
    particle_scores.append("Particle: {}, global test score: {} +- {}".format(part,
                                                         scores.mean(axis=0)[0][1],
                                                         scores.std(axis=0)[0][1]))
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/xgboost/core.py:614: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase memory consumption")
# 100%|██████████| 3/3 [08:00<00:00, 160.08s/it]
# 100%|██████████| 3/3 [07:51<00:00, 157.07s/it]
# 100%|██████████| 3/3 [03:54<00:00, 78.16s/it]
# 100%|██████████| 3/3 [03:36<00:00, 72.21s/it]

# %%
for res in particle_scores:
    print(res)
# Out:
# Particle: kaon, global test score: 0.9421098224714549 +- 0.0002625777372308681
# Particle: pion, global test score: 0.9667066817734082 +- 0.0006091081500151739
# Particle: proton, global test score: 0.9327065929122972 +- 0.0022375737987852303
# Particle: muon, global test score: 0.9536106854223484 +- 0.0007542547992256032
